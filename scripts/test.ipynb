# %%
import pandas as pd

# %%
df = pd.read_csv("wikipedia_tea_articles.csv")

# %%
df.head(5)
# Out:
#                 title                                               url  \
# 0                 Tea                 https://en.wikipedia.org/wiki/Tea
# 1       Blueberry tea       https://en.wikipedia.org/wiki/Blueberry_tea
# 2   Camellia sinensis   https://en.wikipedia.org/wiki/Camellia_sinensis
# 3  Camellia taliensis  https://en.wikipedia.org/wiki/Camellia_taliensis
# 4       Candida theae       https://en.wikipedia.org/wiki/Candida_theae
#
#                                              summary  \
# 0  Tea is an aromatic beverage prepared by pourin...
# 1  The blueberry tea  is a cocktail made from tea...
# 2  Camellia sinensis is a species of evergreen sh...
# 3  Camellia taliensis (also known as Yunnan large...
# 4  Candida theae is a species of yeast in the gen...
#
#                                            full_text
# 0  Tea is an aromatic beverage prepared by pourin...
# 1  The blueberry tea is a cocktail made from tea ...
# ...
